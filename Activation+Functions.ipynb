# %% [markdown]
# # Activation Functions

# %% [markdown]
# ###### My Notes on Activation Function

# %% [markdown]
# ![activation.jpg](attachment:activation.jpg)

# %% [markdown]
# ![activation2.jpg](attachment:activation2.jpg)

# %% [markdown]
# ![activation3.jpg](attachment:activation3.jpg)
